# %%
while True:
    word = input("Enter a word (must contain at least one uppercase letter): ")
    
    if any(char.isupper() for char in word):
        print("Thank you!")
        break
    else:
        print("Error: The word must contain at least one uppercase letter.\n")
# Out:
# Error: The word must contain at least one uppercase letter.
#
# Thank you!

# %%
# Out:
# No, the input does not contain 'hello'.

# %%
# Out:
# ❌ Password does not meet the requirements:
# - Must be at least 8 characters long
#
#
# ❌ Password does not meet the requirements:
# - Must contain at least one uppercase letter
#
#
# ❌ Password does not meet the requirements:
# - Must be at least 8 characters long
#
#
# ❌ Password does not meet the requirements:
# - Must contain at least one number
#
#
# ❌ Password does not meet the requirements:
# - Must contain at least one special character
